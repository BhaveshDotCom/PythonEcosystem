# %%
import numpy as np
import pandas as pd
from dotenv import load_dotenv
load_dotenv(override=True)
import os

# %% [markdown]
# #### pandas.read_csv()

# %%
# local CSV
train_data = pd.read_csv(os.getenv("AUG_TRAIN_FILE_PATH"))

# %%
# Server 
import requests
from io import StringIO

url = r"https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"
}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

train = pd.read_csv(data)

# %%
np.random.seed(42)
url = r"https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
pd.read_csv(url).sample(5)

# %% [markdown]
# ##### sep parameter

# %%
url = os.getenv("MOVIES_DATA_FILE_PATH")
pd.read_csv(url, sep="\t", names=["Movie ID","Movie Name","Release Year", "Rating","Votes","Genres"])

# %%
train_data = os.getenv("AUG_TRAIN_FILE_PATH")
pd.read_csv(train_data, index_col="enrollee_id").sort_index().sample(5)

# %%
marks = pd.read_csv(os.getenv("MARKS_DATA_FILE_PATH"), header=1)
marks

# %%
pd.read_csv(train_data, usecols=['education_level','major_discipline','company_type']).sample(5)

# %%
pd.read_csv(train_data).head(5)
pd.read_csv(train_data, skiprows=[1,3]).head(5)

# %%
# pd.read_csv(data, encoding='latin-1')

# %%
data = os.getenv("PARSE_DATA_PATH")
pd.read_csv(data, on_bad_lines="skip")

# %% [markdown]
# ##### Huge Dataset

# %%
data = pd.read_csv(os.getenv("MARKS_DATA_FILE_PATH"),header=1, chunksize=16)
for chunk in data:
    print(chunk.shape)
