# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Categorical Plot

# %%
# Datasets
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")

# %% [raw]
# Categorical data is data that classifies observations into distinct groups or categories rather than measuring
# quantities. Examples include gender, color, and product type.

# %% [markdown]
# ### Categorical Scatter Plot

# %%
# stripplot
# axex level function
sns.stripplot(data=tips, x='day', y='total_bill', hue='day', jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(kind="strip", data=tips, x="day", y="total_bill", hue="sex")

# %% [raw]
# Strip Plot
# Used to visualize the distribution of a numerical variable across one or morecategorical
# variables
# Input: 1 categorical column + 1 numerical column
# Displays every individual data point.
# Uses jitter (small random horizontal/vertical noise) to separate overlapping points,
# making dense regions easier to see.

# %%
sns.catplot(kind="swarm",data=tips, x="day", y="total_bill", hue="sex")

# %% [raw]
# Swarm Plot (Seaborn swarmplot)
#
# Used to visualize the distribution of a numerical variable across one or more categorical
# variables.
# Input: 1 categorical column + 1 numerical column.
# Displays every individual data point.
# Automatically adjusts point positions to prevent overlap, so each observation is clearly
# visible (no random jitter).

# %% [markdown]
# ### Categorical Distribution Plot

# %% [raw]
# Boxplot
#
# A box plot is a statistical graph used to summarize the distribution of a numerical
# variable across one or more categories. It displays the median, quartiles, interquartile
# range (IQR), whiskers, and outliers, making it easy to compare distributions.
#
# 1. Median (Q2)
# The line inside the box.
# Represents the middle value (50th percentile) of the data.
#
# 2. First Quartile (Q1)
# The bottom edge of the box.
# 25% of the data lies below Q1.
#
# 3. Third Quartile (Q3)
# The top edge of the box.
# 75% of the data lies below Q3.
#
# 4. Interquartile Range (IQR)
# Represents the spread of the middle 50% of the data.
#
# Formula:   IQR=Q3−Q1
#
# 5. Whiskers
# Extend from the box to the smallest and largest values that are not outliers.
# Typically end at:
# Lower limit = Q1 − 1.5 × IQR
# Upper limit = Q3 + 1.5 × IQR
#
# 6. Outliers
# Data points lying outside the whiskers.
# Displayed as individual dots.
#
# A box plot summarizes the data using five-number statistics (minimum, Q1, median, Q3,
# and maximum within whiskers) instead of displaying every individual observation.

# %%
# sns.catplot(kind="box",data=tips, x="day", y="total_bill", hue="sex")
ax = sns.boxplot(data=tips, x="day", y="total_bill", hue="sex")

# %%
sns.boxplot(data=tips, y="tip")
# Out:
# <Axes: ylabel='tip'>

# %% [raw]
# A violin plot is used to visualize the distribution of a numerical variable across one or
# more categories. It combines a box plot with a kernel density estimate (KDE) to show both
# the summary statistics and the shape of the data distribution.

# %%
sns.violinplot(data=tips,x="sex", y="total_bill", hue="day")
# sns.violinplot(data=tips,x="sex", y="total_bill", hue="day", split=True)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [raw]
# Outer violin shape: Shows the probability density (distribution) of the data.
# Wider sections → More data points are concentrated there (higher density).
# Narrower sections → Fewer data points (lower density).
# White dot/line in the center: Represents the median (50th percentile).
# Thick black box: Represents the Interquartile Range (IQR), from Q1 (25th percentile) to Q3
# (75th percentile).
# Thin black line (whiskers): Shows the range of the data (or whisker limits, depending on
# the settings).

# %%
sns.violinplot(data=tips,x="sex", y="total_bill")
sns.swarmplot(data=tips,x="sex", y="total_bill")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### Categorical Estimate Plot

# %% [raw]
# Barplot
#
# used to compare a numerical value across different categories. It displays the estimated
# value (usually the mean by default) for each category using rectangular bars.
#
# The bar height represents the estimated value of the numerical variable for each category.
#
# The error bar is the vertical line on top of each bar that shows the uncertainty or
# variability of the estimated value.
#
# By default, Seaborn shows a 95% confidence interval (CI) using bootstrap sampling.
# Short error bar → Estimate is more reliable (less variability).
# Long error bar → Estimate is less reliable (more variability).

# %%
sns.barplot(data=tips,x="sex", y="total_bill", hue="smoker")
# sns.barplot(data=tips,x="sex", y="total_bill", hue="smoker", errorbar=None)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.pointplot(data=tips, x="sex", y="total_bill", hue="smoker",estimator="mean", errorbar=None)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# countplot
sns.countplot(data=tips, x="sex", hue="day")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.catplot(data=tips, x="sex", y="total_bill", col="smoker", kind="bar", row="time")
