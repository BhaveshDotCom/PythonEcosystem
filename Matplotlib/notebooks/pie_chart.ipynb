# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from dotenv import load_dotenv
load_dotenv(override=True)
plt.style.use("ggplot")

# %% [markdown]
# ## Pie Chart

# %%
runs_df = pd.DataFrame({
    "Batsman":["ABD", "Gayle", "Rampaul", "Tiwary", "Dilshan", "Kohli"],
    "Batsman_run": [31,175,0,2,33,11]
})
runs_df
# Out:
#    Batsman  Batsman_run
# 0      ABD           31
# 1    Gayle          175
# 2  Rampaul            0
# 3   Tiwary            2
# 4  Dilshan           33
# 5    Kohli           11

# %%
plt.pie(runs_df["Batsman_run"], labels=runs_df["Batsman"], autopct='%0.1f%%')

# %%
plt.pie(runs_df["Batsman_run"], labels=runs_df["Batsman"], autopct='%0.1f%%', explode=[0,0,0,0,0.3,0])
